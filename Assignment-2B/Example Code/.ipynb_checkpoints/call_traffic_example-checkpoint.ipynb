# %%
# define the standard library for machine learning
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# define the machine learning model (regression tree)
from sklearn.tree import DecisionTreeRegressor

# define the model selection and evaluation libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from regress_traffic import traffic_regression_tree

# %% [markdown]
# ### call the prediction e.g., for 1st of october 2006, for the location number 2 at 00:15
#
# for the traffic_regression_tree function:
# 1st entry is the date in the format mm/dd/yyyy
#
# 2nd is the index for location (number only)
#
# 3rd is the index for the time from 0 to 95

# %%
prediction = traffic_regression_tree('10/1/2006',1,1)
print(int(prediction))
# Out:
# 32
